# %%
# pandas - it is a library used for data analysis
import numpy as np
import pandas as pd

# %%
# Series - series  is a column in a table. it is a kind of 1d array
#list
country = ['India','Pak','Usa']
pd.Series(country)
# Out:
# 0    India
# 1      Pak
# 2      Usa
# dtype: object

# %%
run = [12,34,56,22,78]
pd.Series(run)
# Out:
# 0    12
# 1    34
# 2    56
# 3    22
# 4    78
# dtype: int64

# %%
marks = [12,45,78,34]
sub = ['maths','english','science','hindi']
pd.Series(marks,index=sub)
# Out:
# maths      12
# english    45
# science    78
# hindi      34
# dtype: int64

# %%
mark = pd.Series(marks,index=sub,name='Nitish ke marks')
mark
# Out:
# maths      12
# english    45
# science    78
# hindi      34
# Name: Nitish ke marks, dtype: int64

# %%
#dictionary

marks = {'maths' : 23,
        'english' : 56,
        'science' : 78}
pd.Series(marks)
# Out:
# maths      23
# english    56
# science    78
# dtype: int64

# %%
marks
# Out:
# {'maths': 23, 'english': 56, 'science': 78}

# %%
mark.size
# Out:
# 4

# %%
mark.dtype
# Out:
# dtype('int64')

# %%
mark.name
# Out:
# 'Nitish ke marks'

# %%
mark.is_unique
# Out:
# True

# %%
mark.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
run.index
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
mark.values
# Out:
# array([12, 45, 78, 34], dtype=int64)

# %%
# import datasets

bd = pd.read_csv('bollywood.csv',index_col='movie',squeeze=True)
k = pd.read_csv('kohli_ipl.csv',index_col='match_no',squeeze=True)
subs = pd.read_csv('subs.csv',squeeze = True)
# Out:
# C:\AppData\Local\Temp\ipykernel_19580\3286882272.py:3: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   bd = pd.read_csv('bollywood.csv',index_col='movie',squeeze=True)
# C:\AppData\Local\Temp\ipykernel_19580\3286882272.py:4: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   k = pd.read_csv('kohli_ipl.csv',index_col='match_no',squeeze=True)
# C:\AppData\Local\Temp\ipykernel_19580\3286882272.py:5: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   subs = pd.read_csv('subs.csv',squeeze = True)

# %%
bd
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
subs.head(7)
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# 5    46
# 6    33
# Name: Subscribers gained, dtype: int64

# %%
k.tail(9)
# Out:
# match_no
# 207     0
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
bd.sample()
# Out:
# movie
# Jabariya Jodi    Sidharth Malhotra
# Name: lead, dtype: object

# %%
bd.value_counts()
# Out:
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: lead, Length: 566, dtype: int64

# %%
k.sort_values(ascending=False).head(3).values[0]
# Out:
# 113

# %%
bd.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
k.count()
# Out:
# 215

# %%
subs.sum()
# Out:
# 49510

# %%
k.product()
# Out:
# 0

# %%
subs.mean()
# Out:
# 135.64383561643837

# %%
k.median()
# Out:
# 24.0

# %%
bd.mode()
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: object

# %%
subs.std()
# Out:
# 62.6750230372527

# %%
k.var()
# Out:
# 688.0024777222343

# %%
subs.min()
# Out:
# 33

# %%
subs.max()
# Out:
# 396

# %%
k.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
x = pd.Series([12,13,14,15,16,89])
x[1]
# Out:
# 13

# %%
bd[0]
# Out:
# 'Vicky Kaushal'

# %%
bd[-1]
# Out:
# 'Akshay Kumar'

# %%
k[5:15]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# Name: runs, dtype: int64

# %%
k[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
bd[-5::2]
# Out:
# movie
# Hum Tumhare Hain Sanam    Shah Rukh Khan
# Saathiya (film)             Vivek Oberoi
# Awara Paagal Deewana        Akshay Kumar
# Name: lead, dtype: object

# %%
k[[1,3,5,7]]
# Out:
# match_no
# 1     1
# 3    13
# 5     1
# 7    34
# Name: runs, dtype: int64

# %%
mark
# Out:
# maths      12
# english    45
# science    78
# hindi      34
# Name: Nitish ke marks, dtype: int64

# %%
mark[1] = 100

# %%
mark
# Out:
# maths       12
# english    100
# science     78
# hindi       34
# Name: Nitish ke marks, dtype: int64

# %%
mark['sst'] = 90

# %%
mark
# Out:
# maths       12
# english    100
# science     78
# hindi       34
# sst         90
# Name: Nitish ke marks, dtype: int64

# %%
len(subs)
# Out:
# 365

# %%
type(subs)
# Out:
# pandas.core.series.Series

# %%
dir(subs)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
sorted(subs)
# Out:
# [33,
#  33,
#  35,
#  37,
#  39,
#  40,
#  40,
#  40,
#  40,
#  42,
#  42,
#  43,
#  44,
#  44,
#  44,
#  45,
#  46,
#  46,
#  48,
#  49,
#  49,
#  49,
#  49,
#  50,
#  50,
#  50,
#  51,
#  54,
#  56,
#  56,
#  56,
#  56,
#  57,
#  61,
#  62,
#  64,
#  65,
#  65,
#  66,
#  66,
#  66,
#  66,
#  67,
#  68,
#  70,
#  70,
#  70,
#  71,
#  71,
#  72,
#  72,
#  72,
#  72,
#  72,
#  73,
#  74,
#  74,
#  75,
#  76,
#  76,
#  76,
#  76,
#  77,
#  77,
#  78,
#  78,
#  78,
#  79,
#  79,
#  80,
#  80,
#  80,
#  81,
#  81,
#  82,
#  82,
#  83,
#  83,
#  83,
#  84,
#  84,
#  84,
#  85,
#  86,
#  86,
#  86,
#  87,
#  87,
#  87,
#  87,
#  88,
#  88,
#  88,
#  88,
#  88,
#  89,
#  89,
#  89,
#  90,
#  90,
#  90,
#  90,
#  91,
#  92,
#  92,
#  92,
#  93,
#  93,
#  93,
#  93,
#  95,
#  95,
#  96,
#  96,
#  96,
#  96,
#  97,
#  97,
#  98,
#  98,
#  99,
#  99,
#  100,
#  100,
#  100,
#  101,
#  101,
#  101,
#  102,
#  102,
#  103,
#  103,
#  104,
#  104,
#  104,
#  105,
#  105,
#  105,
#  105,
#  105,
# ...

# %%
subs.min()
# Out:
# 33

# %%
list(marks)
# Out:
# ['maths', 'english', 'science']

# %%
bd
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
'Battalion 609' in bd
# Out:
# True

# %%
'Shah Rukh Khan' in bd.values
# Out:
# True

# %%
for i in bd:
    print(i)
# Out:
# Vicky Kaushal
# Vicky Ahuja
# Anupam Kher
# Emraan Hashmi
# Mona Ambegaonkar
# Geetika Vidya Ohlyan
# Arshad Warsi
# Radhika Apte
# Kangana Ranaut
# Nawazuddin Siddiqui
# Ali Asgar
# Ranveer Singh
# Prit Kamani
# Ajay Devgn
# Sushant Singh Rajput
# Amitabh Bachchan
# Abhimanyu Dasani
# Talha Arshad Reshi
# Nawazuddin Siddiqui
# Garima Agarwal
# Rasika Agashe
# Barun Sobti
# Akshay Kumar
# Zaheer Iqbal
# Vidyut Jammwal
# Deepika Amin
# Manav Kaul
# Naseeruddin Shah
# Varun Dhawan
# Shreyas Talpade
# Tiger Shroff
# Boman Irani
# Ajay Devgn
# Arjun Kapoor
# Gavie Chahal
# Prabhu Deva
# Shahid Kapoor
# Ayushmann Khurrana
# Anupam Kher
# Karanvir Bohra
# Hrithik Roshan
# Jimmy Sheirgill
# John Abraham
# Rishi Kapoor
# Kangana Ranaut
# Natalia Janoszek
# Diljit Dosanjh
# Sidharth Malhotra
# Rajeev Khandelwal
# Zaira Wasim
# Akshay Kumar
# Jacqueline Fernandez
# Ayushmann Khurrana
# Akshaye Khanna
# Sonam Kapoor
# Karan Deol
# Sanjay Dutt
# Bhavesh Kumar
# Sanaya Irani
# Ayushmann Khurrana
# ...

# %%
for i in bd.index:
    print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
100 - mark
# Out:
# maths      88
# english     0
# science    22
# hindi      66
# sst        10
# Name: Nitish ke marks, dtype: int64

# %%
k[k >= 50]
# Out:
# match_no
# 15      50
# 34      58
# 41      71
# 44      56
# 45      67
# 52      70
# 57      57
# 68      73
# 71      51
# 73      58
# 74      65
# 80      57
# 81      93
# 82      99
# 85      56
# 97      67
# 99      73
# 103     51
# 104     62
# 110     82
# 116     75
# 117     79
# 119     80
# 120    100
# 122     52
# 123    108
# 126    109
# 127     75
# 128    113
# 129     54
# 131     54
# 132     62
# 134     64
# 137     55
# 141     58
# 144     57
# 145     92
# 148     68
# 152     70
# 160     84
# 162     67
# 164    100
# 175     72
# 178     90
# 182     50
# 188     72
# 197     51
# 198     53
# 209     58
# 213     73
# Name: runs, dtype: int64

# %%
k[k == 0].size
# Out:
# 9

# %%
subs[subs > 200].size
# Out:
# 59

# %%
a = bd.value_counts()
a[a > 20]
# Out:
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: lead, dtype: int64

# %%
subs.plot()
# Out:
# <Axes: >

# %%
bd.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='lead'>
